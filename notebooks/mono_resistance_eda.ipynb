# %% [markdown]
# # Mono resistance EDA
#
# In this POC, we gloss over the resistance towards distinct drugs

# %%
# Import the usual suspects.

from __future__ import print_function
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
sns.set_context('paper')



def print_ln():
    print('-' * 80, '\n')

# %% [markdown]
# ## Data from tb-profiler

# %%
tbprofiler_df = pd.read_json("../data/raw/cohort.tbprofiler.json", encoding="UTF-8")
tbprofiler_df = tbprofiler_df.transpose()
tbprofiler_df.head()
# Out:
#                                      rifampicin  \
# SRR1162996                     rpoB_p.His445Asp
# SRR6356985   rpoB_p.Ser450Leu, rpoC_p.Leu527Val
# SRR10525347                                   -
# SRR5153132                                    -
# SRR10380131                    rpoB_p.Ser450Leu
#
#                                     isoniazid     pyrazinamide  \
# SRR1162996   katG_p.Ser315Thr, fabG1_c.-15C>T  pncA_p.Asp49Gly
# SRR6356985   katG_p.Ser315Thr, fabG1_c.-15C>T                -
# SRR10525347                                 -                -
# SRR5153132                                  -                -
# SRR10380131                  katG_p.Ser315Thr                -
#
#                                   ethambutol     streptomycin  \
# SRR1162996   embA_c.-12C>T, embB_p.Gln497Arg     rrs_r.514a>c
# SRR6356985                  embB_p.Met306Ile  rpsL_p.Lys43Arg
# SRR10525347                                -                -
# SRR5153132                                 -                -
# SRR10380131                 embB_p.Met306Ile  rpsL_p.Lys43Arg
#
#              fluoroquinolones      moxifloxacin         ofloxacin  \
# SRR1162996   gyrB_p.Asp461Asn  gyrB_p.Asp461Asn  gyrB_p.Asp461Asn
# SRR6356985                  -                 -                 -
# SRR10525347                 -                 -                 -
# SRR5153132                  -                 -                 -
# SRR10380131                 -                 -                 -
#
#                  levofloxacin     ciprofloxacin  ...      cycloserine  \
# SRR1162996   gyrB_p.Asp461Asn  gyrB_p.Asp461Asn  ...  alr_p.Leu113Arg
# SRR6356985                  -                 -  ...                -
# SRR10525347                 -                 -  ...                -
# SRR5153132                  -                 -  ...                -
# SRR10380131                 -                 -  ...                -
#
#             linezolid bedaquiline clofazimine delamanid  main_lin  \
# SRR1162996          -           -           -         -  lineage4
# SRR6356985          -           -           -         -  lineage2
# SRR10525347         -           -           -         -  lineage4
# SRR5153132          -           -           -         -  lineage4
# SRR10380131         -           -           -         -  lineage2
#
#                      sublin     drtype MDR XDR
# SRR1162996     lineage4.3.3        XDR   R   R
# SRR6356985     lineage2.2.1        MDR   R
# SRR10525347  lineage4.1.2.1  Sensitive
# SRR5153132   lineage4.1.2.1  Sensitive
# SRR10380131    lineage2.2.1        MDR   R
#
# [5 rows x 26 columns]

# %%
tbprofiler_df.head()
# Out:
#                                      rifampicin  \
# SRR1162996                     rpoB_p.His445Asp
# SRR6356985   rpoB_p.Ser450Leu, rpoC_p.Leu527Val
# SRR10525347                                   -
# SRR5153132                                    -
# SRR10380131                    rpoB_p.Ser450Leu
#
#                                     isoniazid     pyrazinamide  \
# SRR1162996   katG_p.Ser315Thr, fabG1_c.-15C>T  pncA_p.Asp49Gly
# SRR6356985   katG_p.Ser315Thr, fabG1_c.-15C>T                -
# SRR10525347                                 -                -
# SRR5153132                                  -                -
# SRR10380131                  katG_p.Ser315Thr                -
#
#                                   ethambutol     streptomycin  \
# SRR1162996   embA_c.-12C>T, embB_p.Gln497Arg     rrs_r.514a>c
# SRR6356985                  embB_p.Met306Ile  rpsL_p.Lys43Arg
# SRR10525347                                -                -
# SRR5153132                                 -                -
# SRR10380131                 embB_p.Met306Ile  rpsL_p.Lys43Arg
#
#              fluoroquinolones      moxifloxacin         ofloxacin  \
# SRR1162996   gyrB_p.Asp461Asn  gyrB_p.Asp461Asn  gyrB_p.Asp461Asn
# SRR6356985                  -                 -                 -
# SRR10525347                 -                 -                 -
# SRR5153132                  -                 -                 -
# SRR10380131                 -                 -                 -
#
#                  levofloxacin     ciprofloxacin  ...      cycloserine  \
# SRR1162996   gyrB_p.Asp461Asn  gyrB_p.Asp461Asn  ...  alr_p.Leu113Arg
# SRR6356985                  -                 -  ...                -
# SRR10525347                 -                 -  ...                -
# SRR5153132                  -                 -  ...                -
# SRR10380131                 -                 -  ...                -
#
#             linezolid bedaquiline clofazimine delamanid  main_lin  \
# SRR1162996          -           -           -         -  lineage4
# SRR6356985          -           -           -         -  lineage2
# SRR10525347         -           -           -         -  lineage4
# SRR5153132          -           -           -         -  lineage4
# SRR10380131         -           -           -         -  lineage2
#
#                      sublin     drtype MDR XDR
# SRR1162996     lineage4.3.3        XDR   R   R
# SRR6356985     lineage2.2.1        MDR   R
# SRR10525347  lineage4.1.2.1  Sensitive
# SRR5153132   lineage4.1.2.1  Sensitive
# SRR10380131    lineage2.2.1        MDR   R
#
# [5 rows x 26 columns]

# %%
tbprofiler_df.describe().T
# Out:
#                          count unique               top  freq
# rifampicin                2654     69  rpoB_p.Ser450Leu  1026
# isoniazid                 2654     54  katG_p.Ser315Thr  1032
# pyrazinamide              2654    265                 -  1544
# ethambutol                2654     84                 -  1105
# streptomycin              2654     21                 -  1012
# fluoroquinolones          2654     65                 -  1771
# moxifloxacin              2654     65                 -  1771
# ofloxacin                 2654     65                 -  1771
# levofloxacin              2654     65                 -  1771
# ciprofloxacin             2654     65                 -  1771
# aminoglycosides           2654      4                 -  2253
# amikacin                  2654      4                 -  2253
# kanamycin                 2654     23                 -  1605
# capreomycin               2654     43                 -  2194
# ethionamide               2654    106                 -  1638
# para-aminosalicylic_acid  2654     15                 -  2491
# cycloserine               2654      8                 -  2560
# linezolid                 2654      3                 -  2649
# bedaquiline               2654      2                 -  2653
# clofazimine               2654      2                 -  2653
# delamanid                 2654      2                 -  2640
# main_lin                  2654     10          lineage2  1314
# sublin                    2654     53      lineage2.2.1  1288
# drtype                    2654      4               MDR  1038
# MDR                       2654      2                 R  1673
# XDR                       2654      2                    2019

# %%
# What's the dristribution of the main lineages
tbprofiler_df["main_lin"].hist()
# Out:
# <AxesSubplot:>

# %%
# Plot frequencies of drug resistance profiles
tbprofiler_df["drtype"].hist()
# Out:
# <AxesSubplot:>

# %%
# Find the relationship between drtype and main_lin variables
tbprofiler_df.groupby(['drtype','main_lin']).size()
# Out:
# drtype          main_lin
# Drug-resistant  lineage1              14
#                 lineage2             131
#                 lineage2;lineage4      2
#                 lineage3              11
#                 lineage3;lineage4      1
#                 lineage4             135
#                 lineageBOV             1
# MDR             lineage1               6
#                 lineage1;lineage2      1
#                 lineage2             589
#                 lineage2;lineage3      1
#                 lineage2;lineage4     18
#                 lineage3              51
#                 lineage4             372
# Sensitive                              3
#                 lineage1              35
#                 lineage2             225
#                 lineage2;lineage4      2
#                 lineage3              10
#                 lineage4             411
# XDR             lineage1               1
#                 lineage2             369
#                 lineage2;lineage4     12
#                 lineage3              25
#                 lineage4             228
# dtype: int64

# %%
# Find the relationship between drtype and sublin variables

tbprofiler_df.groupby(['drtype','sublin']).size()
# Out:
# drtype          sublin
# Drug-resistant  lineage1.1.1                8
#                 lineage1.1.1.1              2
#                 lineage1.1.2                2
#                 lineage1.2.2                2
#                 lineage2                    1
#                                            ..
# XDR             lineage4.7                  2
#                 lineage4.8                 37
#                 lineage4.8;lineage4.3.3     2
#                 lineage4.9                  2
#                 lineage4;lineage2.2.1       2
# Length: 117, dtype: int64

# %%
pd.crosstab(index= tbprofiler_df.index, columns=tbprofiler_df["drtype"])
# Out:
# drtype      Drug-resistant  MDR  Sensitive  XDR
# row_0
# ERR027458                0    1          0    0
# ERR027459                1    0          0    0
# ERR027460                0    0          1    0
# ERR027461                0    0          1    0
# ERR027462                0    0          1    0
# ...                    ...  ...        ...  ...
# SRR9738553               0    1          0    0
# SRR9738554               1    0          0    0
# SRR9738556               0    0          0    1
# SRR9738557               0    0          0    1
# SRR9738558               1    0          0    0
#
# [2654 rows x 4 columns]

# %%
pd.crosstab(index= tbprofiler_df['main_lin'], columns=tbprofiler_df["drtype"])
# Out:
# drtype             Drug-resistant  MDR  Sensitive  XDR
# main_lin
#                                 0    0          3    0
# lineage1                       14    6         35    1
# lineage1;lineage2               0    1          0    0
# lineage2                      131  589        225  369
# lineage2;lineage3               0    1          0    0
# lineage2;lineage4               2   18          2   12
# lineage3                       11   51         10   25
# lineage3;lineage4               1    0          0    0
# lineage4                      135  372        411  228
# lineageBOV                      1    0          0    0

# %%
# Stacked Column Chart: visual form of the two-way table

pd.crosstab(index= tbprofiler_df['main_lin'], columns=tbprofiler_df["drtype"])\
                .plot(kind="bar", 
                     figsize=(8,8),
                     stacked=True)
# Out:
# <AxesSubplot:xlabel='main_lin'>

# %%
## Find the relationship between sub lineages and drtype variables

pd.crosstab(index= tbprofiler_df['sublin'], columns= tbprofiler_df["drtype"])
# Out:
# drtype                                Drug-resistant  MDR  Sensitive  XDR
# sublin
#                                                    0    0          3    0
# lineage1.1.1                                       8    2         17    0
# lineage1.1.1.1                                     2    0         17    0
# lineage1.1.2                                       2    3          0    0
# lineage1.2.1                                       0    0          1    0
# lineage1.2.2                                       2    1          0    1
# lineage2                                           1    0          0    0
# lineage2.1                                         2    0          7    0
# lineage2.2.1                                     118  587        214  369
# lineage2.2.1.1                                     9    1          1    0
# lineage2.2.1;lineage1.1.1                          0    1          0    0
# lineage2.2.2                                       1    1          3    0
# lineage3                                          11   49         10   19
# lineage3.1                                         0    0          0    2
# lineage3.1.2                                       0    1          0    3
# lineage3.1.2.1                                     0    1          0    1
# lineage3;lineage2.2.1                              0    1          0    0
# lineage4                                           0    7          1    1
# lineage4.1                                         2    8          3    0
# lineage4.1.1.3                                     0    0          0    1
# lineage4.1.2                                       7    1          2    0
# lineage4.1.2.1                                    11   52         59   19
# lineage4.1.2.1;lineage2.2.1                        0    2          0    2
# lineage4.2.1                                      23  145         64  114
# lineage4.2.1;lineage2.2                            0    1          0    0
# lineage4.2.1;lineage2.2.1                          1    6          2    2
# lineage4.2.1;lineage3                              1    0          0    0
# lineage4.2.1;lineage4.1.2.1                        0    2          0    2
# lineage4.2.2                                       2    1          4    0
# lineage4.3.1                                       0    0          1    0
# lineage4.3.3                                      16   73         97   45
# lineage4.3.3;lineage2.2                            1    1          0    0
# lineage4.3.3;lineage2.2.1                          0    3          0    6
# lineage4.3.3;lineage4.2.1                          0    1          0    0
# lineage4.3.3;lineage4.2.2                          0    0          1    0
# lineage4.3.4.1                                     1    0          6    0
# lineage4.3.4.2                                     2    4          0    2
# lineage4.4.1.1                                     3    5          3    1
# lineage4.4.1.2                                     1    0          0    0
# lineage4.4.2                                       2    0          5    0
# lineage4.5                                         2    7          2    0
# lineage4.6                                         0    0          2    0
# lineage4.7                                         1   11          6    2
# lineage4.8                                        61   51        152   37
# lineage4.8;lineage2.2.1                            0    1          0    0
# lineage4.8;lineage4.1.2.1                          0    1          1    0
# lineage4.8;lineage4.2.1                            0    0          1    0
# lineage4.8;lineage4.3.3                            0    1          0    2
# lineage4.8;lineage4.3.3;lineage2.2.1               0    1          0    0
# lineage4.9                                         1    2          1    2
# lineage4.9;lineage2.2.1                            0    1          0    0
# lineage4;lineage2.2.1                              0    2          0    2
# lineageBOV                                         1    0          0    0

# %%
# Stacked Column Chart: visual form of the two-way table

pd.crosstab(index= tbprofiler_df['sublin'], columns= tbprofiler_df["drtype"])\
                .plot(kind="bar", 
                     figsize=(12,12),
                     stacked=True)
# Out:
# <AxesSubplot:xlabel='sublin'>

# %% [markdown]
# ## Tb-portals data

# %%
import json

with open('../data/raw/test_train_genome_ids.json') as f:
    test_train_genome_ids = json.load(f)

# %%
test_train_genome_ids.keys()
# Out:
# dict_keys(['tb_portals', 'htbc'])

# %%
htbc_genomes = test_train_genome_ids['htbc']
tb_portals_genomes = test_train_genome_ids['tb_portals']

# %%
htbc_tbprofiler_df = tbprofiler_df.loc[htbc_genomes]
htbc_tbprofiler_df.head()
# Out:
#                   rifampicin         isoniazid  \
# SRR5065266                 -                 -
# ERR3335748  rpoB_p.Asp435Val  katG_p.Ser315Thr
# SRR5065310                 -                 -
# SRR5065230                 -  katG_p.Ser315Thr
# ERR067722   rpoB_p.Ser450Leu    fabG1_c.-15C>T
#
#                                     pyrazinamide  \
# SRR5065266                                     -
# ERR3335748  pncA_Chromosome:g.2288682_2289102del
# SRR5065310                                     -
# SRR5065230                                     -
# ERR067722                                      -
#
#                                  ethambutol      streptomycin  \
# SRR5065266                                -                 -
# ERR3335748                 embB_p.Gln497Lys   rpsL_p.Lys43Arg
# SRR5065310                                -                 -
# SRR5065230                                -  gid_c.102_102del
# ERR067722   embA_c.-16C>T, embB_p.Met306Ile   rpsL_p.Lys43Arg
#
#            fluoroquinolones     moxifloxacin        ofloxacin  \
# SRR5065266                -                -                -
# ERR3335748  gyrA_p.Asp94Ala  gyrA_p.Asp94Ala  gyrA_p.Asp94Ala
# SRR5065310                -                -                -
# SRR5065230                -                -                -
# ERR067722   gyrA_p.Asp94Gly  gyrA_p.Asp94Gly  gyrA_p.Asp94Gly
#
#                levofloxacin    ciprofloxacin  ... cycloserine linezolid  \
# SRR5065266                -                -  ...           -         -
# ERR3335748  gyrA_p.Asp94Ala  gyrA_p.Asp94Ala  ...           -         -
# SRR5065310                -                -  ...           -         -
# SRR5065230                -                -  ...           -         -
# ERR067722   gyrA_p.Asp94Gly  gyrA_p.Asp94Gly  ...           -         -
#
#            bedaquiline clofazimine delamanid  main_lin          sublin  \
# SRR5065266           -           -         -  lineage1  lineage1.1.1.1
# ERR3335748           -           -         -  lineage3        lineage3
# SRR5065310           -           -         -  lineage1  lineage1.1.1.1
# SRR5065230           -           -         -  lineage4    lineage4.2.2
# ERR067722            -           -         -  lineage2    lineage2.2.1
#
#                     drtype MDR XDR
# SRR5065266       Sensitive
# ERR3335748             MDR   R
# SRR5065310       Sensitive
# SRR5065230  Drug-resistant
# ERR067722              XDR   R   R
#
# [5 rows x 26 columns]

# %%
tb_portals_tbprofiler_df = tbprofiler_df.loc[tb_portals_genomes]
tb_portals_tbprofiler_df.head()
# Out:
#                    rifampicin                         isoniazid pyrazinamide  \
# SRR10379876  rpoB_p.Ser450Leu  katG_p.Ser315Thr, fabG1_c.-15C>T            -
# SRR10379877  rpoB_p.Ser450Leu  katG_p.Ser315Thr, fabG1_c.-15C>T            -
# SRR10379878                 -                                 -            -
# SRR10379879                 -                                 -            -
# SRR10379880                 -                                 -            -
#
#                    ethambutol     streptomycin  \
# SRR10379876  embB_p.Ser297Ala  rpsL_p.Lys88Arg
# SRR10379877  embB_p.Ser297Ala  rpsL_p.Lys88Arg
# SRR10379878                 -                -
# SRR10379879                 -  rpsL_p.Lys88Arg
# SRR10379880                 -                -
#
#                              fluoroquinolones  \
# SRR10379876                   gyrA_p.Asp94Gly
# SRR10379877  gyrA_p.Asp94Gly, gyrA_p.Ala90Val
# SRR10379878                                 -
# SRR10379879                                 -
# SRR10379880                                 -
#
#                                  moxifloxacin  \
# SRR10379876                   gyrA_p.Asp94Gly
# SRR10379877  gyrA_p.Asp94Gly, gyrA_p.Ala90Val
# SRR10379878                                 -
# SRR10379879                                 -
# SRR10379880                                 -
#
#                                     ofloxacin  \
# SRR10379876                   gyrA_p.Asp94Gly
# SRR10379877  gyrA_p.Asp94Gly, gyrA_p.Ala90Val
# SRR10379878                                 -
# SRR10379879                                 -
# SRR10379880                                 -
#
#                                  levofloxacin  \
# SRR10379876                   gyrA_p.Asp94Gly
# SRR10379877  gyrA_p.Asp94Gly, gyrA_p.Ala90Val
# SRR10379878                                 -
# SRR10379879                                 -
# SRR10379880                                 -
#
#                                 ciprofloxacin  ... cycloserine linezolid  \
# SRR10379876                   gyrA_p.Asp94Gly  ...           -         -
# SRR10379877  gyrA_p.Asp94Gly, gyrA_p.Ala90Val  ...           -         -
# SRR10379878                                 -  ...           -         -
# SRR10379879                                 -  ...           -         -
# SRR10379880                                 -  ...           -         -
#
#             bedaquiline clofazimine delamanid           main_lin  \
# SRR10379876           -           -         -           lineage4
# SRR10379877           -           -         -           lineage4
# SRR10379878           -           -         -           lineage2
# SRR10379879           -           -         -  lineage2;lineage4
# SRR10379880           -           -         -           lineage4
#
#                                 sublin          drtype MDR XDR
# SRR10379876               lineage4.2.1             XDR   R   R
# SRR10379877               lineage4.2.1             XDR   R   R
# SRR10379878               lineage2.2.1       Sensitive
# SRR10379879  lineage4.2.1;lineage2.2.1  Drug-resistant
# SRR10379880               lineage4.3.3       Sensitive
#
# [5 rows x 26 columns]

# %% [markdown]
# ### HTBC Genomes

# %%
htbc_tbprofiler_df["main_lin"].hist()
# Out:
# <AxesSubplot:>

# %%
htbc_tbprofiler_df["drtype"].hist()
# Out:
# <AxesSubplot:>

# %%
htbc_tbprofiler_df.groupby(['drtype','main_lin']).size()
# Out:
# drtype          main_lin
# Drug-resistant  lineage1             14
#                 lineage2             62
#                 lineage3             11
#                 lineage4             25
# MDR             lineage1              6
#                 lineage2             74
#                 lineage2;lineage4     6
#                 lineage3             51
#                 lineage4             38
# Sensitive                             2
#                 lineage1             35
#                 lineage2             66
#                 lineage2;lineage4     2
#                 lineage3              9
#                 lineage4             49
# XDR             lineage1              1
#                 lineage2             20
#                 lineage2;lineage4     1
#                 lineage3             25
#                 lineage4              4
# dtype: int64

# %%
# Stacked Column Chart: visual form of the two-way table

pd.crosstab(index= htbc_tbprofiler_df['main_lin'], columns=htbc_tbprofiler_df["drtype"])\
                .plot(kind="bar", 
                     figsize=(8,8),
                     stacked=True)
# Out:
# <AxesSubplot:xlabel='main_lin'>

# %% [markdown]
# ### Tb_portals genomes

# %%
tb_portals_tbprofiler_df["main_lin"].hist()
# Out:
# <AxesSubplot:>

# %%
tb_portals_tbprofiler_df["drtype"].hist()
# Out:
# <AxesSubplot:>

# %%
tb_portals_tbprofiler_df.groupby(['drtype','main_lin']).size()
# Out:
# drtype          main_lin
# Drug-resistant  lineage2              69
#                 lineage2;lineage4      2
#                 lineage3;lineage4      1
#                 lineage4             110
#                 lineageBOV             1
# MDR             lineage1;lineage2      1
#                 lineage2             515
#                 lineage2;lineage3      1
#                 lineage2;lineage4     12
#                 lineage4             334
# Sensitive                              1
#                 lineage2             159
#                 lineage3               1
#                 lineage4             362
# XDR             lineage2             349
#                 lineage2;lineage4     11
#                 lineage4             224
# dtype: int64
